# %% [markdown]
# # 🕵️‍♀️ Top songs spotify 2019
#
# ## 🔍 Explorando os dados
#
# neste dataset tenho:
# - ID
# - Track.Name
# - Artist.Name
# - Genre
# - Beats.Per.Minute
# - Energy: The energy of a song - the higher the value, the more energtic song
# - Danceability: The higher the value, the easier it is to dance to this song
# - Loudness..dB..: The higher the value, the louder the song
# - Liveness: The higher the value, the more likely the song is a live recording
# - Valence.: The higher the value, the more positive mood for the song.
# - Length.: The duration of the song
# - Acousticness..: The higher the value the more acoustic the song is
# - Speechiness.: The higher the value the more spoken word the song contains
# - Popularity: The higher the value the more popular the song is

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter 

df = pd.read_csv("https://raw.githubusercontent.com/beatrizadm/data-analysis/master/data/top50-2019.csv")
df.head()
# Out:
#    Unnamed: 0                       Track.Name  ... Speechiness. Popularity
# 0           1                         Senorita  ...            3         79
# 1           2                            China  ...            9         92
# 2           3    boyfriend (with Social House)  ...           46         85
# 3           4  Beautiful People (feat. Khalid)  ...           19         86
# 4           5      Goodbyes (Feat. Young Thug)  ...            7         94
#
# [5 rows x 14 columns]

# %% [markdown]
# Quais os cantores mais recorrentes nas top songs?

# %%
bar_plot = dict(Counter(df['Artist.Name'].values).most_common(5))
plt.bar(*zip(*bar_plot.items()), color=(0.9,0.8,0.2,0.9))
plt.show()

# %% [markdown]
# O que faz as músicas de ed sheeran terem tanto sucesso em um só ano?

# %%
#ordenando por popularidade
df = df.sort_values('Popularity', ascending=False)
ed_sheeran = df.loc[df["Artist.Name"]=="Ed Sheeran"]
ed_sheeran.head()
# Out:
#     Unnamed: 0  ... Popularity
# 37          38  ...         87
# 3            4  ...         86
# 5            6  ...         84
# 49          50  ...         82
#
# [4 rows x 14 columns]

# %% [markdown]
# Podemos perceber que suas músicas em geral são mais acústicas do que "faladas".

# %%
# Data
track_name = ['Antisocial', 'Beautiful People', "I Don't Care", 'Cross Me']
data=pd.DataFrame({'x': track_name, 'Acousticness': ed_sheeran['Acousticness..'], 'Speechiness': ed_sheeran['Speechiness.'] })
 
# multiple line plot
plt.plot('x', 'Acousticness', data=data, marker='o', markerfacecolor='#561fff', markersize=12, color='#8f93ff', linewidth=4)
plt.plot('x', 'Speechiness', data=data, marker='o', markerfacecolor='purple', markersize=12, color='#e99dff', linewidth=4)
plt.legend()

# %% [markdown]
# Apenas na música "Beautiful People" esse padrão não ocorre.
# Já é conhecido que as músicas de Ed Sheeran tem bastante musicalidade e com ritmo, agora vamos ver a relação de beats por minuto, dançabilidade e energia.

# %%
x = track_name
y = ed_sheeran['Beats.Per.Minute']
z = ed_sheeran['Danceability']
w = ed_sheeran['Valence.']

plt.scatter(x, y, s=y*3, c="green", alpha=0.7, label='Beats por minuto')
plt.scatter(x, z, s=z*3, c="blue", alpha=0.7, label='Dançabilidade')
plt.scatter(x, w, s=w*3, c="red", alpha=0.7, label='Valencia')

plt.legend()
plt.show()

# %% [markdown]
# Logo percebemos que por mais que a música tenha muitos beats por minuto e relativa dançabilidade, não significa que ela terá alta valência, tendo em vista que suas músicas mais reflexivas e que passam mensagens que nem sempre são positivas.
